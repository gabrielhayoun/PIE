# %%
import numpy as np
import pandas as pd
import pandas_datareader.data as web 
import seaborn as sns
import yfinance as yf

from pynance.data import readers

# %%
#stk_tickers = ['TSM', 'NVDA', 'META', 'AMZN', 'TSLA', 'PYPL', 'EA', 'IBM', 'INTC']
# readers.write_stock_txt(stk_tickers, 'tech_us')

# %%
x= readers.read_txt('tech_us')
x
# Out:
# ['MSFT', 'IBM', 'GOOGL', 'AAPL', 'NVDA', 'META', 'AMZN', 'TSLA']

# %%
readers.get_financial_datas(x, start = '1999-01-01', conversion = True)
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# {'MSFT':                 Open      High       Low     Close  Adj Close      Volume
#  1999-01-04       NaN       NaN       NaN       NaN        NaN  69305200.0
#  1999-01-05  2.072184  2.343836  1.928541  4.360134   4.360114  64281600.0
#  1999-01-06  6.497381  3.455725  4.861761  4.342531   4.342549  69064800.0
#  1999-01-07 -0.141722 -0.884207  0.710563 -0.802769  -0.802726  51150400.0
# ...
