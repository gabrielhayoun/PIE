# %% [markdown]
# # Draft on how to get data

# %%
# pandas, pandas_datareader, numpy and matplotlib
import numpy as np
import pandas as pd
from matplotlib import pyplot

# %% [markdown]
# ## panda data reader

# %%
import pandas_datareader.data as web

# %%
stk_tickers = ['MSFT', 'IBM', 'GOOGL']
ccy_tickers = ['DEXJPUS', 'DEXUSUK']
idx_tickers = ['SP500', 'DJIA', 'VIXCLS']

stk_data = web.DataReader(stk_tickers, 'yahoo')
ccy_data = web.DataReader(ccy_tickers, 'fred')
idx_data = web.DataReader(idx_tickers, 'fred')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /Users/gabrielhayoun/Library/Mobile Documents/com~apple~CloudDocs/cours/cours_supaero/3A/PIE/git/pynance/data/draft.ipynb Cellule 5 in <cell line: 5>()
#       <a href='vscode-notebook-cell:/Users/gabrielhayoun/Library/Mobile%20Documents/com~apple~CloudDocs/cours/cours_supaero/3A/PIE/git/pynance/data/draft.ipynb#W4sZmlsZQ%3D%3D?line=1'>2</a> ccy_tickers = ['DEXJPUS', 'DEXUSUK']
#       <a href='vscode-notebook-cell:/Users/gabrielhayoun/Library/Mobile%20Documents/com~apple~CloudDocs/cours/cours_supaero/3A/PIE/git/pynance/data/draft.ipynb#W4sZmlsZQ%3D%3D?line=2'>3</a> idx_tickers = ['SP500', 'DJIA', 'VIXCLS']
# ...

# %%
stk_data
# Out:
# Attributes   Adj Close                              Close              \
# Symbols           MSFT         IBM      GOOGL        MSFT         IBM
# Date
# 2017-11-24   78.407181  114.223793  52.826000   83.260002  145.162521
# 2017-11-27   78.981628  114.329102  53.600498   83.870003  145.296371
# 2017-11-28   79.932777  114.697701  53.164501   84.879997  145.764816
# 2017-11-29   78.482521  115.510124  51.868999   83.339996  146.797318
# 2017-11-30   79.264145  115.826080  51.808498   84.169998  147.198853
# ...                ...         ...        ...         ...         ...
# 2022-11-15  241.290009  144.339996  98.440002  241.970001  144.339996
# 2022-11-16  241.729996  144.520004  98.849998  241.729996  144.520004
# 2022-11-17  241.679993  146.089996  98.360001  241.679993  146.089996
# 2022-11-18  241.220001  147.639999  97.430000  241.220001  147.639999
# 2022-11-21  242.050003  146.679993  95.599998  242.050003  146.679993
#
# ...

# %%
ccy_data
# Out:
#             DEXJPUS  DEXUSUK
# DATE
# 2017-11-23      NaN      NaN
# 2017-11-24   111.54   1.3336
# 2017-11-27   111.00   1.3333
# 2017-11-28   111.13   1.3231
# 2017-11-29   111.75   1.3436
# ...             ...      ...
# 2022-11-14   140.43   1.1728
# 2022-11-15   139.36   1.1890
# 2022-11-16   139.59   1.1889
# 2022-11-17   140.45   1.1812
# 2022-11-18   140.03   1.1902
#
# [1302 rows x 2 columns]

# %%
idx_data
# Out:
#               SP500      DJIA  VIXCLS
# DATE
# 2017-11-23      NaN       NaN     NaN
# 2017-11-24  2602.42  23557.99    9.67
# 2017-11-27  2601.42  23580.78    9.87
# 2017-11-28  2627.04  23836.71   10.03
# 2017-11-29  2626.07  23940.68   10.70
# ...             ...       ...     ...
# 2022-11-15  3991.73  33592.92   24.54
# 2022-11-16  3958.79  33553.83   24.11
# 2022-11-17  3946.56  33546.32   23.93
# 2022-11-18  3965.34  33745.69   23.12
# 2022-11-21  3949.94  33700.28     NaN
#
# [1303 rows x 3 columns]

# %% [markdown]
# Avantages : simple, infos financières complètes tous les jours

# %% [markdown]
# ## Yahoo finance api

# %%
import yfinance as yf

# %%
pfe = yf.Ticker('AAPL')
pfe.info
# Out:
# {'regularMarketPrice': None,
#  'preMarketPrice': None,
#  'logo_url': '',
#  'trailingPegRatio': 2.5348}

# %%
pfe.info['beta']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /Users/gabrielhayoun/Library/Mobile Documents/com~apple~CloudDocs/cours/cours_supaero/3A/PIE/git/pynance/data/draft.ipynb Cellule 13 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/Users/gabrielhayoun/Library/Mobile%20Documents/com~apple~CloudDocs/cours/cours_supaero/3A/PIE/git/pynance/data/draft.ipynb#X15sZmlsZQ%3D%3D?line=0'>1</a> pfe.info['beta']
#
# KeyError: 'beta'

# %%
pfe.info['currency']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /Users/gabrielhayoun/Library/Mobile Documents/com~apple~CloudDocs/cours/cours_supaero/3A/PIE/git/pynance/data/draft.ipynb Cellule 14 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/Users/gabrielhayoun/Library/Mobile%20Documents/com~apple~CloudDocs/cours/cours_supaero/3A/PIE/git/pynance/data/draft.ipynb#X16sZmlsZQ%3D%3D?line=0'>1</a> pfe.info['currency']
#
# KeyError: 'currency'

# %%
pfe.news
# Out:
# [{'uuid': '53e7b36c-9958-353f-9670-5a8270810e42',
#   'title': 'FDA Authorizes Updated Covid-19 Vaccines for Children as Young as 6 Months',
#   'publisher': 'The Wall Street Journal',
#   'link': 'https://finance.yahoo.com/m/53e7b36c-9958-353f-9670-5a8270810e42/fda-authorizes-updated.html',
#   'providerPublishTime': 1670532240,
#   'type': 'STORY',
#   'thumbnail': {'resolutions': [{'url': 'https://s.yimg.com/uu/api/res/1.2/w67E0673df9XBljfZKK3UA--~B/aD02NDA7dz0xMjgwO2FwcGlkPXl0YWNoeW9u/https://media.zenfs.com/en/wsj.com/241bdb7226ffaebf696e0b80dc63be51',
#      'width': 1280,
#      'height': 640,
#      'tag': 'original'},
#     {'url': 'https://s.yimg.com/uu/api/res/1.2/nzvjpmglI1fpRq.3AnCN.Q--~B/Zmk9ZmlsbDtoPTE0MDtweW9mZj0wO3c9MTQwO2FwcGlkPXl0YWNoeW9u/https://media.zenfs.com/en/wsj.com/241bdb7226ffaebf696e0b80dc63be51',
#      'width': 140,
#      'height': 140,
#      'tag': '140x140'}]},
#   'relatedTickers': ['PFE', 'BNTX', 'MRNA']},
# ...

# %%
import datetime

datetime.datetime.fromtimestamp(1670532240)

# %%
pfe.history(period="50mo")
# Out:
#                                 Open       High        Low      Close  \
# Date
# 2018-09-24 00:00:00-04:00  35.720009  36.142731  35.630585  35.711880
# 2018-09-25 00:00:00-04:00  35.874458  36.004529  35.573678  35.598064
# 2018-09-26 00:00:00-04:00  35.638711  36.020786  35.476125  35.508640
# 2018-09-27 00:00:00-04:00  35.598068  35.915109  35.508645  35.687489
# 2018-09-28 00:00:00-04:00  35.711873  35.882589  35.549287  35.825684
# ...                              ...        ...        ...        ...
# 2022-11-15 00:00:00-05:00  49.340000  49.529999  48.180000  48.570000
# 2022-11-16 00:00:00-05:00  48.799999  49.060001  48.049999  48.049999
# 2022-11-17 00:00:00-05:00  47.799999  48.500000  47.529999  48.330002
# 2022-11-18 00:00:00-05:00  48.639999  48.830002  47.869999  48.230000
# 2022-11-21 00:00:00-05:00  48.099998  48.279999  47.720001  48.180000
#
#                              Volume  Dividends  Stock Splits
# Date
# ...

# %%
yf.download('AAPL')
#yf.download('AAPL', start_date, end_date)
# Out:
# [*********************100%***********************]  1 of 1 completed
#                   Open        High         Low       Close   Adj Close  \
# Date
# 1980-12-12    0.128348    0.128906    0.128348    0.128348    0.099874
# 1980-12-15    0.122210    0.122210    0.121652    0.121652    0.094663
# 1980-12-16    0.113281    0.113281    0.112723    0.112723    0.087715
# 1980-12-17    0.115513    0.116071    0.115513    0.115513    0.089886
# 1980-12-18    0.118862    0.119420    0.118862    0.118862    0.092492
# ...                ...         ...         ...         ...         ...
# 2022-12-23  130.919998  132.419998  129.639999  131.860001  131.860001
# 2022-12-27  131.380005  131.410004  128.720001  130.029999  130.029999
# 2022-12-28  129.669998  131.029999  125.870003  126.040001  126.040001
# 2022-12-29  127.989998  130.479996  127.730003  129.610001  129.610001
# 2022-12-30  128.410004  129.949997  127.430000  129.929993  129.929993
#
#                Volume
# Date
# ...

# %% [markdown]
# https://pythoninvest.com/long-read/exploring-finance-apis#popup:subscribe

# %% [markdown]
# ## List of tickers

# %% [markdown]
# Suggestions : potentiellement faire un dictionnaire entre les noms des entreprises et leur acronyme sur la bourse
#
# OU BIEN
#
# utiliser get all tickers api ==> Marche pas

# %%
from get_all_tickers import get_tickers as gt

list_of_tickers = gt.get_tickers(NYSE=False, NASDAQ=False, AMEX=True)
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# /Users/gabrielhayoun/Library/Mobile Documents/com~apple~CloudDocs/3A/PIE/git/pynance/data/draft.ipynb Cellule 18 in <cell line: 3>()
#       <a href='vscode-notebook-cell:/Users/gabrielhayoun/Library/Mobile%20Documents/com~apple~CloudDocs/3A/PIE/git/pynance/data/draft.ipynb#X30sZmlsZQ%3D%3D?line=0'>1</a> from get_all_tickers import get_tickers as gt
# ----> <a href='vscode-notebook-cell:/Users/gabrielhayoun/Library/Mobile%20Documents/com~apple~CloudDocs/3A/PIE/git/pynance/data/draft.ipynb#X30sZmlsZQ%3D%3D?line=2'>3</a> list_of_tickers = gt.get_tickers(NYSE=False, NASDAQ=False, AMEX=True)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/get_all_tickers/get_tickers.py:77, in get_tickers(NYSE, NASDAQ, AMEX)
#      75     tickers_list.extend(__exchange2list('nasdaq'))
#      76 if AMEX:
# ...

# %% [markdown]
# openbb marche bof
